# %%
import pandas as pd

df = pd.read_csv('autos.csv')


print(df)
# Out:
#      symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0            3  alfa-romero       gas        std             2  convertible
# 1            3  alfa-romero       gas        std             2  convertible
# 2            1  alfa-romero       gas        std             2    hatchback
# 3            2         audi       gas        std             4        sedan
# 4            2         audi       gas        std             4        sedan
# ..         ...          ...       ...        ...           ...          ...
# 188         -1        volvo       gas        std             4        sedan
# 189         -1        volvo       gas      turbo             4        sedan
# 190         -1        volvo       gas        std             4        sedan
# 191         -1        volvo    diesel      turbo             4        sedan
# 192         -1        volvo       gas      turbo             4        sedan
#
# ...

# %%
df.head(8)
# Out:
#    symboling         make fuel_type aspiration  num_of_doors   body_style  \
# 0          3  alfa-romero       gas        std             2  convertible
# 1          3  alfa-romero       gas        std             2  convertible
# 2          1  alfa-romero       gas        std             2    hatchback
# 3          2         audi       gas        std             4        sedan
# 4          2         audi       gas        std             4        sedan
# 5          2         audi       gas        std             2        sedan
# 6          1         audi       gas        std             4        sedan
# 7          1         audi       gas        std             4        wagon
#
#   drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 0          rwd           front        88.6   168.8  ...          130
# 1          rwd           front        88.6   168.8  ...          130
# 2          rwd           front        94.5   171.2  ...          152
# ...

# %%
df.tail(8)
# Out:
#      symboling   make fuel_type aspiration  num_of_doors body_style  \
# 185         -1  volvo       gas        std             4      wagon
# 186         -2  volvo       gas      turbo             4      sedan
# 187         -1  volvo       gas      turbo             4      wagon
# 188         -1  volvo       gas        std             4      sedan
# 189         -1  volvo       gas      turbo             4      sedan
# 190         -1  volvo       gas        std             4      sedan
# 191         -1  volvo    diesel      turbo             4      sedan
# 192         -1  volvo       gas      turbo             4      sedan
#
#     drive_wheels engine_location  wheel_base  length  ...  engine_size  \
# 185          rwd           front       104.3   188.8  ...          141
# 186          rwd           front       104.3   188.8  ...          130
# 187          rwd           front       104.3   188.8  ...          130
# ...

# %%
 df.groupby('make')['price'].min()
print(min_price_df)
# Out:
#              make  min_price
# 0     alfa-romero      13495
# 1            audi      13950
# 2             bmw      16430
# 3       chevrolet       5151
# 4           dodge       5572
# 5           honda       5399
# 6           isuzu       6785
# 7          jaguar      32250
# 8           mazda       5195
# 9   mercedes-benz      25552
# 10        mercury      16503
# 11     mitsubishi       5389
# 12         nissan       5499
# 13         peugot      11900
# 14       plymouth       5572
# 15        porsche      22018
# 16           saab      11850
# 17         subaru       5118
# 18         toyota       5348
# 19     volkswagen       7775
# 20          volvo      12940

# %%
df.min_std = stds.min()
print('The smallest standard deviation of the prices is:', min_std)
# Out:
# The smallest standard deviation of the prices is: 1676.8283892533195

# %%
df[['make', 'fuel_type']].tail(2)
# Out:
#       make fuel_type
# 191  volvo    diesel
# 192  volvo       gas

# %%
dit={'make': ['audi', 'Honda', 'porsche', 'nissan'],
                    'year': [2022, 2021, 2020, 2019],
                    'price': [75000, 88000, 92000, 10000]}
dit2 ={'make': ['audi', 'Honda', 'porsche', 'nissan'],
                    'mpg': [23, 24, 29, 25],
                    'transmission': ['automatic', 'manual', 'manual', 'automatic']}
df1=pd.DataFrame(dit)
df2=pd.DataFrame(dit2)
merged_df = pd.merge(df1, df2, on='make')

print(merged_df)
# Out:
#       make  year  price  mpg transmission
# 0     audi  2022  75000   23    automatic
# 1    Honda  2021  88000   24       manual
# 2  porsche  2020  92000   29       manual
# 3   nissan  2019  10000   25    automatic
